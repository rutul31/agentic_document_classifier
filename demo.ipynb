# %% [markdown]
# # Document Classification Assistant Demo
# This notebook simulates test cases TC1–TC5 using the modular pipeline.

# %%
from pathlib import Path
from src.classifier import DualLLMClassifier
from src.hitl_feedback import FeedbackRepository
from src.preprocess import DocumentBundle
from src.prompt_tree import PromptTree
from src.main import load_settings, get_prompt_tree

settings = load_settings()
repository = FeedbackRepository('sqlite:///:memory:')
classifier = DualLLMClassifier(settings.primary_model, settings.secondary_model, repository)
prompt_tree = get_prompt_tree()

test_cases = {
    'TC1': 'This policy is public and contains general guidelines.',
    'TC2': 'The document is confidential and references an NDA.',
    'TC3': 'This report includes salary data and employee SSN numbers.',
    'TC4': 'Incident response log detailing a suspected malware breach.',
    'TC5': 'Marketing flyer with no sensitive information.',
}

results = {}
for case, text in test_cases.items():
    bundle = DocumentBundle(text=text)
    result = classifier.classify(bundle, prompt_tree, Path(f'{case}.txt'))
    results[case] = result.to_json()

results
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       4 from src.preprocess import DocumentBundle
#       5 from src.prompt_tree import PromptTree
# ----> 6 from src.main import load_settings, get_prompt_tree
#       8 settings = load_settings()
#       9 repository = FeedbackRepository('sqlite:///:memory:')
#
# File ~/Desktop/agentic_document_classifier/src/main.py:189
#     185         await asyncio.sleep(0)
#     186     LOGGER.info("Batch job %s complete", job_id)
# --> 189 app = create_app()
#     192 __all__ = [
#     193     "CLASSIFICATION_LABELS",
#     194     "ClassificationResult",
#    (...)    197     "load_settings",
#     198 ]
#
# File ~/Desktop/agentic_document_classifier/src/main.py:119, in create_app()
#     117 repository = FeedbackRepository()
#     118 classifier = create_classifier(settings, repository)
# --> 119 prompt_tree = get_prompt_tree()
#     121 @app.post("/classify")
#     122 async def classify(request: ClassificationRequest) -> Dict[str, object]:
#     123     """Classify a single document."""
#
# File ~/Desktop/agentic_document_classifier/src/main.py:101, in get_prompt_tree(path)
#      98 def get_prompt_tree(path: pathlib.Path = PROMPT_LIBRARY_PATH) -> PromptTree:
#      99     """Load the default prompt tree."""
# --> 101     return PromptTree.from_yaml(str(path))
#
# File ~/Desktop/agentic_document_classifier/src/prompt_tree.py:64, in PromptTree.from_yaml(cls, path)
#      61 """Load a prompt tree from a YAML file."""
#      63 LOGGER.debug("Loading prompt tree from %s", path)
# ---> 64 data = load_yaml(path)
#      65 return cls.from_dict(data)
#
# File ~/Desktop/agentic_document_classifier/src/utils/simple_yaml.py:105, in load(path)
#     103 with open(path, "r", encoding="utf-8") as handle:
#     104     content = handle.read().splitlines()
# --> 105 data, _ = parse_block(content, 0, 0)
#     106 return data
#
# File ~/Desktop/agentic_document_classifier/src/utils/simple_yaml.py:86, in parse_block(lines, start, indent)
#      84     break
#      85 if ":" not in line:
# ---> 86     raise ValueError(f"Invalid line: {line}")
#      87 key, remainder = line.split(":", 1)
#      88 key = key.strip()
#
# ValueError: Invalid line: You are a document classification expert. Review the document content and assess risk levels.
